# %%
import pandas as pd

# %%
df_links = pd.read_csv('data2.csv')

# %%
df_links
# Out:
#                                                  data
# 0   https://www.avto.net/Ads/prepare_results_makes...
# 1   https://www.avto.net/Ads/prepare_results_makes...
# 2   https://www.avto.net/Ads/prepare_results_makes...
# 3   https://www.avto.net/Ads/prepare_results_makes...
# 4   https://www.avto.net/Ads/prepare_results_makes...
# ..                                                ...
# 87  https://www.avto.net/Ads/prepare_results_makes...
# 88  https://www.avto.net/Ads/prepare_results_makes...
# 89  https://www.avto.net/Ads/prepare_results_makes...
# 90  https://www.avto.net/Ads/prepare_results_makes...
# 91  https://www.avto.net/Ads/prepare_results_makes...
#
# [92 rows x 1 columns]

# %%
brands = []
for i in df_links.data:
    brands.append(i.split('=')[1])

# %%
brands
# Out:
# ['Abarth',
#  'AEV',
#  'Aixam',
#  'AlfaRomeo',
#  'Alpine',
#  'AstonMartin',
#  'Audi',
#  'Austin',
#  'Bentley',
#  'BMW',
#  'Buick',
#  'Cadillac',
#  'Chevrolet',
#  'Chrysler',
#  'Citroen',
#  'Cupra',
#  'Dacia',
#  'Daewoo',
#  'Daihatsu',
#  'DFSK',
#  'DKW',
#  'Dodge',
#  'DS Automobiles',
#  'EV',
#  'Ferrari',
#  'Fiat',
#  'Fisker',
#  'Ford',
#  'GMC',
#  'Grecav',
#  'Honda',
#  'Hummer',
#  'Hyundai',
#  'Infiniti',
#  'Isuzu',
#  'Iveco',
#  'JAC',
#  'Jaguar',
#  'Jeep',
#  'Kia',
#  'Lada',
#  'Lamborghini',
#  'Lancia',
#  'LandRover',
#  'Lexus',
#  'Ligier',
#  'Lincoln',
#  'Mahindra',
#  'Maserati',
#  'Mazda',
#  'McLaren',
#  'MercedesBenz',
#  'MG',
#  'Microcar',
#  'Mini',
#  'Mitsubishi',
#  'Nissan',
#  'Oldsmobile',
#  'Opel',
#  'Peugeot',
#  'Piaggio',
#  'Plymouth',
#  'Pontiac',
#  'Porsche',
#  'Proton',
#  'Puch',
#  'Renault',
#  'Replica',
#  'RollsRoyce',
#  'Rosengart',
#  'Rover',
#  'Saab',
#  'Seat',
#  'Smart',
#  'Ssangyong',
# ...

# %%
link = "https://www.avto.net/Ads/results.asp?znamka=Bmw&model=&modelID=&tip=&znamka2=&model2=&tip2=&znamka3=&model3=&tip3=&cenaMin=0&cenaMax=999999&letnikMin=0&letnikMax=2090&bencin=0&starost2=999&oblika=0&ccmMin=0&ccmMax=99999&mocMin=&mocMax=&kmMin=0&kmMax=9999999&kwMin=0&kwMax=999&motortakt=0&motorvalji=0&lokacija=0&sirina=0&dolzina=&dolzinaMIN=0&dolzinaMAX=100&nosilnostMIN=0&nosilnostMAX=999999&lezisc=&presek=0&premer=0&col=0&vijakov=0&EToznaka=0&vozilo=&airbag=&barva=&barvaint=&EQ1=1000000000&EQ2=1000000000&EQ3=1000000000&EQ4=1000000000&EQ5=1000000000&EQ6=1000000000&EQ7=1110100120&EQ8=1000000001&EQ9=1000000000&KAT=1010000000&PIA=&PIAzero=&PSLO=&akcija=0&paketgarancije=&broker=0&prikazkategorije=0&kategorija=0&ONLvid=0&ONLnak=0&zaloga=10&arhiv=0&presort=&tipsort=&stran="

# %%
#new_links.append(link.replace('Bmw',i))
with open("url.txt", "w") as text_file:
    for i in brands:
        text_file.write("\n")
        text_file.write(link.replace('Bmw',i))

# %%
new_links
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6e1674e134f6> in <module>()
# ----> 1 new_links
#
# NameError: name 'new_links' is not defined

# %%
df = pd.read_csv('test_run3.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
# features      23 non-null object
# price         20 non-null object
# prodajalec    12 non-null object
# title         23 non-null object
# dtypes: object(4)
# memory usage: 864.0+ bytes

# %%
df['prodajalec'][1]
# Out:
# '    '

# %%
df['price_num'] = df['price'].map(split('€')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-562785670356> in <module>()
# ----> 1 df['price_num'] = df['price'].map(split('€')[0])
#
# NameError: name 'split' is not defined

# %%
df['features'][0]
# Out:
# '                                                  Starost:              rabljeno             Prva registracija:                   2018 / 11                                              Leto proizvodnje:                   2018                    Prevoženi km:            26000                         Tehnični pregled:                   2022 / 7                  Motor:              132 kW             (179 KM),  1400  ccm            Gorivo:              bencinski motor            Menjalnik:              avtomatski menjalnik            Oblika:              kombilimuzina / hatchback            Št.vrat:              3 vr.            Barva:               metalik            Notranjost:               / usnje                              Kraj ogleda:              1000 Ljubljana                   ,                             Vprašajte prodajalca za VIN in pridobite CARFAX poročilo o zgodovini vozila.                                            ,                    Podvozje:                
# ...

# %%
# Out:
#                                                   reg letnik  \
# 0   Starost:              rabljeno             Prv...
# 1   Starost:              rabljeno / ima jamstvo  ...
# 2   Starost:              rabljeno             Prv...
# 3   Starost:              rabljeno             Prv...
# 4   Starost:              rabljeno             Prv...
# 5   Starost:              rabljeno / ima garancijo...
# 6   Starost:              rabljeno             Prv...
# 7   Starost:              rabljeno             Prv...
# 8   Starost:              rabljeno             Prv...
# 9   Starost:              rabljeno             Prv...
# 10  Starost:              rabljeno             Prv...
# 11
# 12  Starost:              rabljeno / ima garancijo...
# 13  Starost:              rabljeno             Prv...
# 14  Starost:              rabljeno             Prv...
# 15  Starost:              rabljeno             Prv...
# 16  Starost:              rabljeno / ima garancijo...
# ...

# %%
# Out:
#                                                  reg letnik  \
# 0  Starost:              rabljeno             Prv...
# 1  Starost:              rabljeno / ima jamstvo  ...
# 2  Starost:              rabljeno             Prv...
# 3  Starost:              rabljeno             Prv...
# 4  Starost:              rabljeno             Prv...
#
#                                              Starost  \
# 0                rabljeno             Prva regist...
# 1                rabljeno / ima jamstvo          ...
# 2                rabljeno             Prva regist...
# 3                rabljeno             Prva regist...
# 4                rabljeno             Prva regist...
#
#                                             tehnicni  \
# 0  Starost:              rabljeno             Prv...
# 1  Starost:              rabljeno / ima jamstvo  ...
# 2  Starost:              rabljeno             Prv...
# 3
# 4  Starost:              rabljeno             Prv...
#
# ...
